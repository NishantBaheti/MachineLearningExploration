# %% [markdown]
# # Curse Of Dimensionality
#
# `TBD`

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
axes = [1, 1, 1]

data = np.ones(axes)
l = data * 0.3

fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection='3d')

ax.voxels(data, alpha=0.6)

plt.show();
